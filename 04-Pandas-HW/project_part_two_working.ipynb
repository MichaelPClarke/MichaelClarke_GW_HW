# %% [markdown]
# ## Python Mini-Project: Data Clean-Up, Pt. 2
#
# Pay close attention to the prompts to help guide you through this task.

# %%
# Dependencies
import pandas as pd

# %%
# load CSV
file = "Resources/2016-FCC-New-Coders-Survey-Data.csv"

# %%
# Read with pandas--low_memory required to suppress errors about mixed data types
# You may need to encode this file
file_df = pd.read_csv(file, low_memory=False)
file_df.head()
# Out:
#     Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 0  28.0               0.0             NaN                   NaN
# 1  22.0               0.0             NaN                   NaN
# 2  19.0               0.0             NaN                   NaN
# 3  26.0               0.0             NaN                   NaN
# 4  20.0               0.0             NaN                   NaN
#
#    BootcampLoanYesNo  BootcampMonthsAgo BootcampName  BootcampPostSalary  \
# 0                NaN                NaN          NaN                 NaN
# 1                NaN                NaN          NaN                 NaN
# 2                NaN                NaN          NaN                 NaN
# 3                NaN                NaN          NaN                 NaN
# 4                NaN                NaN          NaN                 NaN
#
#    BootcampRecommend  ChildrenNumber  ... ResourceSoloLearn  \
# 0                NaN             NaN  ...               NaN
# ...

# %%
# Take only columns 0, 1, 2, 3, 4, 6, 7, 8, 9, 10, 11, 29, 30, 32, 36, 37, 45, 48, 56, 110, 111
# Consider using iloc
columns_df = file_df.iloc[:,[0, 1, 2, 3, 4, 6, 7, 8, 9, 10, 11, 29, 30, 32, 36, 37, 45, 48, 56, 110, 111]]
columns_df
# Out:
#         Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 0      28.0               0.0             NaN                   NaN
# 1      22.0               0.0             NaN                   NaN
# 2      19.0               0.0             NaN                   NaN
# 3      26.0               0.0             NaN                   NaN
# 4      20.0               0.0             NaN                   NaN
# ...     ...               ...             ...                   ...
# 15615  39.0               0.0             NaN                   NaN
# 15616  27.0               0.0             NaN                   NaN
# 15617  37.0               0.0             NaN                   NaN
# 15618  26.0               0.0             NaN                   NaN
# 15619  22.0               0.0             NaN                   NaN
#
#        BootcampLoanYesNo BootcampName  BootcampPostSalary  BootcampRecommend  \
# ...

# %%
# Change reading 0 and 1 to No and Yes, respectively
cleaned_df = columns_df.replace(to_replace=[0, 1], value=["No","Yes"])
cleaned_df
# Out:
#         Age AttendedBootcamp BootcampFinish BootcampFullJobAfter  \
# 0      28.0               No            NaN                  NaN
# 1      22.0               No            NaN                  NaN
# 2      19.0               No            NaN                  NaN
# 3      26.0               No            NaN                  NaN
# 4      20.0               No            NaN                  NaN
# ...     ...              ...            ...                  ...
# 15615  39.0               No            NaN                  NaN
# 15616  27.0               No            NaN                  NaN
# 15617  37.0               No            NaN                  NaN
# 15618  26.0               No            NaN                  NaN
# 15619  22.0               No            NaN                  NaN
#
#       BootcampLoanYesNo BootcampName  BootcampPostSalary BootcampRecommend  \
# 0                   NaN          NaN                 NaN               NaN
# ...

# %%
# Extract rows for only those who attended a bootcamp
attended_df = cleaned_df[cleaned_df["AttendedBootcamp"]=="Yes"]
attended_df
# Out:
#         Age AttendedBootcamp BootcampFinish BootcampFullJobAfter  \
# 93     32.0              Yes            Yes                   No
# 97     26.0              Yes            Yes                  Yes
# 130    41.0              Yes            Yes                  Yes
# 159    26.0              Yes            Yes                   No
# 188    24.0              Yes             No                  NaN
# ...     ...              ...            ...                  ...
# 15539  39.0              Yes            Yes                  Yes
# 15540  24.0              Yes            Yes                  Yes
# 15541  23.0              Yes            Yes                  Yes
# 15593  29.0              Yes             No                  NaN
# 15600  28.0              Yes            Yes                  Yes
#
#       BootcampLoanYesNo              BootcampName  BootcampPostSalary  \
# 93                   No            Codify Academy                 NaN
# ...

# %%
# Create DataFrame of the various boot camps along with the number of participants (enrollees)
# Create a DataFrame from using value_counts
#attendees_df = attended_df.groupby(['BootcampName'])

numattendees_df = attended_df['BootcampName'].value_counts()
numattendees_df.reset_index()
summary_df = pd.DataFrame({"Attendees": numattendees_df})
summary_df.reset_index()
summary_df
# Out:
#                                           Attendees
# General Assembly                                 90
# Flatiron School                                  54
# Dev Bootcamp                                     48
# The Iron Yard                                    40
# Prime Digital Academy                            30
# ...                                             ...
# Austin Coding Academy                             1
# Betamore                                          1
# Launch School (formerly Tealeaf Academy)          1
# Ladies Learning Code                              1
# Base10 Academy                                    1
#
# [128 rows x 1 columns]

# %%
# Count how many attendees of each bootcamp would recommend the bootcamp
#grouped_df = attended_df.groupby['BootcampName']
rec_attendees_df = attended_df[attended_df["BootcampRecommend"]=="Yes"]
rec_attendees_df
rec_attendees2_df = rec_attendees_df["BootcampName"].value_counts()
rec_attendees2_df
attendees_sum_df = pd.DataFrame({"Recommenders": rec_attendees2_df})
attendees_sum_df
# Out:
#                   Recommenders
# General Assembly            70
# Flatiron School             50
# Dev Bootcamp                41
# The Iron Yard               31
# Hack Reactor                27
# ...                        ...
# Coding House                 1
# Digital House                1
# Betamore                     1
# Starter League               1
# Base10 Academy               1
#
# [116 rows x 1 columns]

# %%
# Merge the two created data frames on the name of tbe bootcamp
combined_df = pd.merge(summary_df, attendees_sum_df)
combined_df
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# <ipython-input-18-8f00891cfec7> in <module>
#       1 # Merge the two created data frames on the name of tbe bootcamp
# ----> 2 combined_df = pd.merge(summary_df, attendees_sum_df)
#       3 combined_df
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      84         copy=copy,
#      85         indicator=indicator,
# ---> 86         validate=validate,
#      87     )
#      88     return op.get_result()
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     618             warnings.warn(msg, UserWarning)
#     619
# ...

# %%
# Calculate percentage of each bootcamp's students who are recommenders
# Think of what should be the numerator and the demoninator
final_df = combined_df.sort_values("% Recommend", ascending=False)
#final_df.head()
# Sort results in descending order

# Format for percentages
final_df["% Recommend"] = table_df["% Recommend"].map("{:,.2f}%".format)
final_df.head()

# %%
# Export to excel and remove index
final_df.to_excel("Output/hw_output2.xls", index=False, header=True)
